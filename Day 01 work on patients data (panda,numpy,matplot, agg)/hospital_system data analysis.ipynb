# %% [markdown]
# ## At very first read the file before performe transform process

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
patients = pd.read_csv(r'C:\Users\my pc\Downloads\archive\patients.csv')

# %%
patients
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# ...

# %%
patients.head(11)
# Out:
#       patient_id               name  age arrival_date departure_date  \
# 0   PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1   PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2   PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3   PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4   PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# 5   PAT-f4b29bae          Diana May   83   2025-06-26     2025-06-30
# 6   PAT-283cda07    William Herrera   62   2025-12-26     2025-12-27
# 7   PAT-5b61868c      Ashley Waller    0   2025-05-21     2025-06-04
# 8   PAT-f9c8afa6       Victor Baker   50   2025-07-30     2025-08-13
# 9   PAT-5290be70   Jeffrey Chandler   29   2025-11-01     2025-11-14
# 10  PAT-003ce690        Larry Dixon   29   2025-01-19     2025-01-21
#
#              service  satisfaction
# 0            surgery            61
# 1            surgery            83
# ...

# %%
patients.describe()
# Out:
#                age  satisfaction
# count  1000.000000   1000.000000
# mean     45.337000     79.597000
# std      25.999912     11.550325
# min       0.000000     60.000000
# 25%      23.000000     70.000000
# 50%      46.000000     80.000000
# 75%      68.000000     89.250000
# max      89.000000     99.000000

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      1000 non-null   object
#  1   name            1000 non-null   object
#  2   age             1000 non-null   int64
#  3   arrival_date    1000 non-null   object
#  4   departure_date  1000 non-null   object
#  5   service         1000 non-null   object
#  6   satisfaction    1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
patients.iloc[[3],0:]
# Out:
#      patient_id             name  age arrival_date departure_date    service  \
# 3  PAT-3dda2bb5  Crystal Johnson   32   2025-10-12     2025-10-23  emergency
#
#    satisfaction
# 3            81

# %%
service = patients['service']
service
# Out:
# 0               surgery
# 1               surgery
# 2      general_medicine
# 3             emergency
# 4                   ICU
#              ...
# 995           emergency
# 996           emergency
# 997                 ICU
# 998                 ICU
# 999    general_medicine
# Name: service, Length: 1000, dtype: object

# %%
type(service)
# Out:
# pandas.core.series.Series

# %%
service = patients[['service']]
service
# Out:
#               service
# 0             surgery
# 1             surgery
# 2    general_medicine
# 3           emergency
# 4                 ICU
# ..                ...
# 995         emergency
# 996         emergency
# 997               ICU
# 998               ICU
# 999  general_medicine
#
# [1000 rows x 1 columns]

# %%
type(service)
# Out:
# pandas.core.frame.DataFrame

# %%
patients[['service','satisfaction']]
# Out:
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# 2    general_medicine            83
# 3           emergency            81
# 4                 ICU            76
# ..                ...           ...
# 995         emergency            91
# 996         emergency            99
# 997               ICU            69
# 998               ICU            61
# 999  general_medicine            83
#
# [1000 rows x 2 columns]

# %%
patients.shape
# Out:
# (1000, 7)

# %%
patients.values
# Out:
# array([['PAT-09484753', 'Richard Rodriguez', 24, ..., '2025-03-22',
#         'surgery', 61],
#        ['PAT-f0644084', 'Shannon Walker', 6, ..., '2025-12-14',
#         'surgery', 83],
#        ['PAT-ac6162e4', 'Julia Torres', 24, ..., '2025-07-05',
#         'general_medicine', 83],
#        ...,
#        ['PAT-8f07e894', 'Jennifer James', 72, ..., '2025-12-21', 'ICU',
#         69],
#        ['PAT-4ae301e1', 'Kara Hernandez', 47, ..., '2025-02-20', 'ICU',
#         61],
#        ['PAT-e2ef9c5f', 'Lorraine Turner', 64, ..., '2025-05-08',
#         'general_medicine', 83]], shape=(1000, 7), dtype=object)

# %%
patients.columns
# Out:
# Index(['patient_id', 'name', 'age', 'arrival_date', 'departure_date',
#        'service', 'satisfaction'],
#       dtype='object')

# %%
patients_Surgery = patients['service'] == 'surgery'
Age_less_50 = patients['age'] < 50
patients[patients_Surgery & Age_less_50]
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 14   PAT-cc50ad71        Helen Jones   31   2025-06-11     2025-06-23
# 26   PAT-13c9b20f      Robert Potter   10   2025-07-14     2025-07-21
# 28   PAT-1bc22a80      David Alvarez    8   2025-02-22     2025-03-06
# ..            ...                ...  ...          ...            ...
# 965  PAT-90ba3a0f      Brandon Kelly   15   2025-03-12     2025-03-25
# 970  PAT-b2fe6226     Kathryn Dillon   15   2025-12-22     2026-01-05
# 973  PAT-596d9b6a         Keith Knox   37   2025-04-26     2025-05-05
# 976  PAT-c0ec69bd         Mark Smith   21   2025-11-20     2025-12-03
# 988  PAT-5a0ce14d      Stephen Cowan   39   2025-06-20     2025-07-01
#
#      service  satisfaction
# 0    surgery            61
# 1    surgery            83
# 14   surgery            92
# ...

# %%
patients_Surgery = patients['service'] == 'surgery'
Age_gret_50 = patients['age'] > 50
patients[patients_Surgery & Age_gret_50]
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 31   PAT-736d270f  David Douglas Jr.   80   2025-04-25     2025-04-26
# 33   PAT-eacf84b5  Christopher Rubio   72   2025-10-05     2025-10-16
# 36   PAT-029113eb    Victoria Larson   84   2025-12-22     2025-12-31
# 45   PAT-48f61d27     Michelle Brown   53   2025-02-24     2025-03-04
# 49   PAT-84559395        Jamie Smith   72   2025-03-14     2025-03-23
# ..            ...                ...  ...          ...            ...
# 967  PAT-7fcb5d8b       David Carter   76   2025-01-21     2025-01-26
# 971  PAT-c378810a        Edwin Brown   86   2025-05-21     2025-06-01
# 977  PAT-4abfea64     Philip Jackson   76   2025-05-17     2025-05-27
# 986  PAT-a4976bc6       Rodney Evans   52   2025-07-18     2025-07-20
# 991  PAT-c7aac776      Darryl Acosta   83   2025-10-11     2025-10-20
#
#      service  satisfaction
# 31   surgery            73
# 33   surgery            63
# 36   surgery            97
# ...

# %%
patients_Surgery = patients['service'] == 'surgery'
Age_gret_50 = patients['age'] > 50
satisfactions = patients['satisfaction'] > 90
patients[patients_Surgery & Age_gret_50 & satisfactions]
# Out:
#        patient_id              name  age arrival_date departure_date  service  \
# 36   PAT-029113eb   Victoria Larson   84   2025-12-22     2025-12-31  surgery
# 49   PAT-84559395       Jamie Smith   72   2025-03-14     2025-03-23  surgery
# 155  PAT-feaf8fa9       Joshua Reed   69   2025-07-30     2025-08-05  surgery
# 236  PAT-623cbc11       Sharon Boyd   89   2025-02-11     2025-02-18  surgery
# 265  PAT-86ba2b6b        Paul Lewis   53   2025-01-25     2025-02-07  surgery
# 329  PAT-a674e677      Jason Rhodes   80   2025-01-14     2025-01-23  surgery
# 360  PAT-5ce1547c     Veronica King   76   2025-02-13     2025-02-22  surgery
# 374  PAT-ec245e75   Jasmine Beltran   73   2025-05-24     2025-05-27  surgery
# 459  PAT-f804d47a   Michael Johnson   81   2025-11-20     2025-12-04  surgery
# 535  PAT-20e12483        Kim Morrow   71   2025-02-21     2025-02-25  surgery
# 578  PAT-894839fd   Katherine Stark   56   2025-01-12     2025-01-23  surgery
# ...

# %%
patients_Surgery = patients['service'] == 'surgery'
Age_less_30 = patients['age'] <30 
satisfactions = patients['satisfaction'] > 90
patients[patients_Surgery & Age_less_30 & satisfactions]
# Out:
#        patient_id                  name  age arrival_date departure_date  \
# 28   PAT-1bc22a80         David Alvarez    8   2025-02-22     2025-03-06
# 34   PAT-8029775b          Amber Wright   25   2025-01-29     2025-02-11
# 76   PAT-46bf225d     Jonathan Peterson   29   2025-11-20     2025-11-22
# 199  PAT-2143a928          Dawn Summers    3   2025-01-19     2025-01-25
# 243  PAT-5b8fca34       Michael Farrell    7   2025-10-27     2025-11-06
# 282  PAT-cdb97e8c           Brian Smith   20   2025-11-10     2025-11-18
# 291  PAT-a2ce687a        Craig Morrison    9   2025-11-10     2025-11-22
# 306  PAT-38efddd3       Gwendolyn Klein    1   2025-09-26     2025-10-01
# 308  PAT-26a57bc7         Jeffrey Mills   10   2025-09-28     2025-09-29
# 353  PAT-c2c67af5        Taylor Carlson    3   2025-08-19     2025-08-26
# 389  PAT-45c8f5a0         Phillip Berry   26   2025-12-29     2026-01-06
# 392  PAT-4155dae7  Mr. Justin Green III    3   2025-09-03     2025-09-06
# ...

# %%
patients_Emergency = patients['service'] == 'emergency'
Age_less_30 = patients['age'] <30 
satisfactions = patients['satisfaction'] > 90
patients[patients_Emergency & Age_less_30 & satisfactions]
# Out:
#        patient_id             name  age arrival_date departure_date  \
# 43   PAT-87783e44     Devon Flores   25   2025-05-29     2025-06-09
# 50   PAT-581a47d8   Paul Castaneda   16   2025-08-05     2025-08-18
# 91   PAT-64d84602   Ricky Davis II   28   2025-07-14     2025-07-23
# 96   PAT-8f6d5fa4    Bryan Herrera   27   2025-03-22     2025-03-24
# 140  PAT-aecf2749     Isaiah Avila   19   2025-07-21     2025-07-29
# 146  PAT-d70a9eaa  Susan Murray MD    5   2025-09-19     2025-09-28
# 177  PAT-3791a5a1   Carolyn Miller   27   2025-04-17     2025-04-22
# 263  PAT-2cbbc8fb    Sergio Knight    9   2025-10-08     2025-10-21
# 333  PAT-c3e8e421  Holly Valentine   25   2025-08-18     2025-08-23
# 466  PAT-8a8a2306  Thomas Peterson   26   2025-01-02     2025-01-15
# 589  PAT-bdf625cd  Brent Hernandez   10   2025-06-30     2025-07-08
# 714  PAT-0b1acdd9  Aaron Schroeder    1   2025-02-27     2025-03-10
# 726  PAT-268d03da  Danielle Watson   24   2025-11-07     2025-11-21
# ...

# %%
patients_icu = patients['service'] == 'ICU'
Age_less_30 = patients['age'] <30 
satisfactions = patients['satisfaction'] > 90
patients[patients_icu & Age_less_30 & satisfactions]
# Out:
#        patient_id                name  age arrival_date departure_date  \
# 32   PAT-af250ef4  Patricia Rodriguez    8   2025-08-25     2025-09-03
# 44   PAT-33d8d801         Brenda Hall   10   2025-06-13     2025-06-14
# 70   PAT-f316dd98   Alexander Collins   17   2025-04-06     2025-04-09
# 100  PAT-9503b40f   Christopher Smith   18   2025-06-17     2025-06-29
# 228  PAT-69035998        Scott Thomas   18   2025-08-30     2025-09-04
# 255  PAT-47b2e0ba       Kenneth Lewis   25   2025-11-07     2025-11-13
# 290  PAT-c13dc9cd         Robin Young    1   2025-02-17     2025-03-02
# 292  PAT-e0bb6975       Mary Thompson   20   2025-07-22     2025-07-29
# 301  PAT-c5ea2d51         Lisa Hunter    7   2025-05-18     2025-05-24
# 305  PAT-e8f195d7      Antonio Garcia   20   2025-05-20     2025-05-31
# 307  PAT-bcef354b       Carrie Wright   15   2025-10-15     2025-10-27
# 332  PAT-edbad772     Robert Harrison    3   2025-01-24     2025-01-30
# ...

# %%
patient_serve = patients['service'] == 'emergency'
Age_gret_50 = patients['age'] > 50
satisfactions = patients['satisfaction'] < 70
patients[patient_serve & Age_gret_50 & satisfactions]
# Out:
#        patient_id                name  age arrival_date departure_date  \
# 6    PAT-283cda07     William Herrera   62   2025-12-26     2025-12-27
# 18   PAT-af65396f      Cameron Fisher   53   2025-08-27     2025-09-01
# 107  PAT-e084c2a6          Mark Brown   77   2025-01-12     2025-01-19
# 232  PAT-55a00f9c      Anthony Harmon   77   2025-09-11     2025-09-20
# 238  PAT-ab6cb480         James Parks   69   2025-07-15     2025-07-28
# 239  PAT-3765ddaf  Theodore Jones Jr.   59   2025-01-27     2025-02-01
# 280  PAT-02f2e75d       Thomas Atkins   70   2025-03-27     2025-04-01
# 289  PAT-6bab5523         Hannah Luna   63   2025-04-30     2025-05-09
# 304  PAT-57b9eff8       Erica Alvarez   77   2025-06-18     2025-06-27
# 335  PAT-98895bae       Tracy Montoya   59   2025-01-20     2025-01-21
# 351  PAT-bda786d0       Eric Williams   63   2025-02-18     2025-02-23
# 371  PAT-0faa8c27       Howard Norman   85   2025-01-17     2025-01-19
# ...

# %%
patients.count('index')
# Out:
# patient_id        1000
# name              1000
# age               1000
# arrival_date      1000
# departure_date    1000
# service           1000
# satisfaction      1000
# dtype: int64

# %%
patients.sort_values(by='age')
# Out:
#        patient_id                name  age arrival_date departure_date  \
# 7    PAT-5b61868c       Ashley Waller    0   2025-05-21     2025-06-04
# 394  PAT-2eab6131  Katherine Martinez    0   2025-04-19     2025-04-26
# 354  PAT-ac3dafd9          Jose Allen    0   2025-11-09     2025-11-13
# 521  PAT-6fc0d4bc         Joyce Brown    0   2025-02-06     2025-02-19
# 783  PAT-137f292a        Cassie Brock    0   2025-03-04     2025-03-10
# ..            ...                 ...  ...          ...            ...
# 679  PAT-65dd44b9      Clayton Steele   89   2025-06-06     2025-06-16
# 620  PAT-2d4ae2a6        Jerry Peters   89   2025-01-17     2025-01-19
# 775  PAT-434171f6       Kenneth Sharp   89   2025-05-26     2025-06-09
# 880  PAT-41173daa      Carmen Preston   89   2025-10-26     2025-10-30
# 996  PAT-87fa07bd        Martha Smith   89   2025-11-18     2025-11-30
#
#               service  satisfaction
# 7                 ICU            82
# 394  general_medicine            80
# ...

# %%
patients.sort_values(by='age', ascending=False, na_position='first')
# Out:
#        patient_id            name  age arrival_date departure_date  \
# 996  PAT-87fa07bd    Martha Smith   89   2025-11-18     2025-11-30
# 449  PAT-92f8e4bd    Louis Martin   89   2025-12-07     2025-12-12
# 529  PAT-1b2fe77a  Janet Kane DVM   89   2025-07-03     2025-07-15
# 195  PAT-112d537f   Kevin Oconnor   89   2025-08-08     2025-08-10
# 236  PAT-623cbc11     Sharon Boyd   89   2025-02-11     2025-02-18
# ..            ...             ...  ...          ...            ...
# 521  PAT-6fc0d4bc     Joyce Brown    0   2025-02-06     2025-02-19
# 653  PAT-487252c6   Jessica Smith    0   2025-06-16     2025-06-29
# 354  PAT-ac3dafd9      Jose Allen    0   2025-11-09     2025-11-13
# 633  PAT-a7f5edb5  Valerie Taylor    0   2025-10-07     2025-10-18
# 7    PAT-5b61868c   Ashley Waller    0   2025-05-21     2025-06-04
#
#               service  satisfaction
# 996         emergency            99
# 449  general_medicine            68
# 529         emergency            93
# ...

# %%
patient_serve_date = patients['arrival_date'] == pd.to_datetime(patients['arrival_date'])
Age_less_50 = patients['age'] < 50
satisfactions = patients['satisfaction'] < 70 
patients[patient_serve_date & Age_less_50 & satisfactions]
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 10   PAT-003ce690        Larry Dixon   29   2025-01-19     2025-01-21
# 12   PAT-69dc0dc1        April Frost   37   2025-11-15     2025-11-19
# 13   PAT-95afe21e    Michelle Harmon    7   2025-02-24     2025-03-03
# 16   PAT-3223420e     Michelle Evans    7   2025-11-09     2025-11-16
# ..            ...                ...  ...          ...            ...
# 954  PAT-3fb1487b     Rebekah Greene   44   2025-07-28     2025-08-11
# 974  PAT-a432ced1     Eugene Baldwin    8   2025-02-19     2025-02-21
# 988  PAT-5a0ce14d      Stephen Cowan   39   2025-06-20     2025-07-01
# 989  PAT-0307a640      Steven Howard   11   2025-10-10     2025-10-11
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
#
#               service  satisfaction
# 0             surgery            61
# 10                ICU            60
# ...

# %%
patients_Surgery = patients[patients['service'] == 'surgery']
print(patients_Surgery)
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 14   PAT-cc50ad71        Helen Jones   31   2025-06-11     2025-06-23
# 26   PAT-13c9b20f      Robert Potter   10   2025-07-14     2025-07-21
# 28   PAT-1bc22a80      David Alvarez    8   2025-02-22     2025-03-06
# ..            ...                ...  ...          ...            ...
# 976  PAT-c0ec69bd         Mark Smith   21   2025-11-20     2025-12-03
# 977  PAT-4abfea64     Philip Jackson   76   2025-05-17     2025-05-27
# 986  PAT-a4976bc6       Rodney Evans   52   2025-07-18     2025-07-20
# 988  PAT-5a0ce14d      Stephen Cowan   39   2025-06-20     2025-07-01
# 991  PAT-c7aac776      Darryl Acosta   83   2025-10-11     2025-10-20
#
#      service  satisfaction
# 0    surgery            61
# 1    surgery            83
# 14   surgery            92
# ...

# %%
patients_Surgery = patients[patients['service'] == 'emergency']
print(patients_Surgery)
# Out:
#        patient_id              name  age arrival_date departure_date  \
# 3    PAT-3dda2bb5   Crystal Johnson   32   2025-10-12     2025-10-23
# 5    PAT-f4b29bae         Diana May   83   2025-06-26     2025-06-30
# 6    PAT-283cda07   William Herrera   62   2025-12-26     2025-12-27
# 9    PAT-5290be70  Jeffrey Chandler   29   2025-11-01     2025-11-14
# 13   PAT-95afe21e   Michelle Harmon    7   2025-02-24     2025-03-03
# ..            ...               ...  ...          ...            ...
# 962  PAT-3ef63f63   Catherine Davis   35   2025-01-08     2025-01-13
# 985  PAT-b87126f2     James Chapman   80   2025-12-14     2025-12-15
# 994  PAT-2fa08c0d       Shawn Scott   79   2025-01-22     2025-01-31
# 995  PAT-a01bf534        Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd      Martha Smith   89   2025-11-18     2025-11-30
#
#        service  satisfaction
# 3    emergency            81
# 5    emergency            81
# 6    emergency            66
# ...

# %%
patients_Surgery = patients[patients['service'] == 'ICU']
print(patients_Surgery)
# Out:
#        patient_id               name  age arrival_date departure_date service  \
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25     ICU
# 7    PAT-5b61868c      Ashley Waller    0   2025-05-21     2025-06-04     ICU
# 10   PAT-003ce690        Larry Dixon   29   2025-01-19     2025-01-21     ICU
# 20   PAT-5e3f8747   Elizabeth Kelley   34   2025-03-29     2025-04-12     ICU
# 24   PAT-f70aeea1    Rebecca Jackson   18   2025-02-05     2025-02-18     ICU
# ..            ...                ...  ...          ...            ...     ...
# 990  PAT-110d5794        Travis Hull   48   2025-11-12     2025-11-18     ICU
# 992  PAT-8700b93a  Nicholas Lawrence    9   2025-10-25     2025-11-02     ICU
# 993  PAT-e5d6a9cf       Jacob Santos   76   2025-12-27     2026-01-02     ICU
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21     ICU
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20     ICU
#
#      satisfaction
# ...

# %%
patients_Surgery = patients[patients['service'] == 'general_medicine']
print(patients_Surgery)
# Out:
#        patient_id             name  age arrival_date departure_date  \
# 2    PAT-ac6162e4     Julia Torres   24   2025-06-29     2025-07-05
# 8    PAT-f9c8afa6     Victor Baker   50   2025-07-30     2025-08-13
# 11   PAT-18f78014    Kenneth Scott   77   2025-06-24     2025-06-26
# 12   PAT-69dc0dc1      April Frost   37   2025-11-15     2025-11-19
# 15   PAT-0beb4754     Erin Edwards   86   2025-10-15     2025-10-17
# ..            ...              ...  ...          ...            ...
# 980  PAT-b3ba89f4    Vincent Reyes   60   2025-12-05     2025-12-10
# 981  PAT-1d5f8550    Curtis Watson   65   2025-05-18     2025-05-20
# 983  PAT-0af52f3d     Michael Sims   30   2025-03-29     2025-03-30
# 989  PAT-0307a640    Steven Howard   11   2025-10-10     2025-10-11
# 999  PAT-e2ef9c5f  Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 2    general_medicine            83
# 8    general_medicine            91
# 11   general_medicine            61
# ...

# %%
patients['age'].mean()
# Out:
# np.float64(45.337)

# %%
patients['age'].median()
# Out:
# np.float64(46.0)

# %%
patients['age'].mode()
# Out:
# 0    10
# Name: age, dtype: int64

# %%
patients['age'].min()
# Out:
# np.int64(0)

# %%
patients['age'].max()
# Out:
# np.int64(89)

# %%
patients.age.var()
# Out:
# np.float64(675.9954264264264)

# %%
patients
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# ...

# %%
patients.age.sum()
# Out:
# np.int64(45337)

# %%
patients.age.std()
# Out:
# np.float64(25.99991204651328)

# %%
plt.figure(figsize=(10,6))
plt.hist(patients['age'], bins=[0,20,40,60,80,100], color='skyblue', edgecolor='black')
plt.title('Age Distribution of Patients')
plt.xlabel('Age Range')
plt.ylabel('Number of Patients')
plt.grid(True)
plt.show()

# %%
bins = [0,20,40,60,80,100]
labels = ['0-20','21-40','41-60','61-80','81-100']
patients['age_group'] = pd.cut(patients['age'], bins=bins, labels=labels, include_lowest=True)

## count 
age_counts = patients['age_group'].value_counts().sort_index() 

plt.figure(figsize=(10,6))
age_counts.plot(kind='bar', color='lightgrey', edgecolor='darkblue')
plt.title('Age Distribution')
plt.xlabel('Age Range')
plt.ylabel('Number of Patients')
plt.grid(axis='y')
plt.show()

# %%
bins = [0,20,40,60,80,100]
labels = ['0-20','21-40','41-60','61-80','81-100']
patients['age_group'] = pd.cut(patients['age'], bins=bins, labels=labels, include_lowest=True)

# count per patient by service type and age group
service_age = patients.groupby(['service','age_group']).size().reset_index(name='count')

# count per patient service type with their percentage level
total_per_service = service_age.groupby('service')['count'].transform('sum')
service_age['percentage'] = (service_age['count']/total_per_service * 100)
# Out:
# C:\Users\my pc\AppData\Local\Temp\ipykernel_8624\1139496188.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   service_age = patients.groupby(['service','age_group']).size().reset_index(name='count')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='age_group', y='percentage', hue='service', data=service_age)
plt.title('Age Group Percentage Distribution by Service Type')
plt.xlabel('Age Group')
plt.ylabel('Percentage of Patients')

plt.show()

# %%
## checking how many people with age percentage 50% stand in this dataset

def pct70(column):return column.quantile(0.7)

# %%
patients['age'].agg(pct70)
# Out:
# np.float64(63.0)

# %%
age_count = patients['age_group'].value_counts(normalize=False).sort_index() 
age_percent = patients['age_group'].value_counts(normalize=True).sort_index() * 100

# %%
## combine both to display age group with people count and percentage

age_summary = pd.DataFrame({
          'count' : age_count,
          'Percentage': age_percent
                
     
})
print(age_summary)
# Out:
#            count  Percentage
# age_group
# 0-20         223        22.3
# 21-40        222        22.2
# 41-60        217        21.7
# 61-80        233        23.3
# 81-100       105        10.5

# %%
plt.figure(figsize=(8,8))
plt.pie(
    age_summary['count'],
    labels=age_summary.index,
    autopct = '%1.1f%%', 
    startangle=90,
    colors=plt.cm.Pastel2.colors,
    wedgeprops={'width':0.4},
    shadow=True
)
plt.title('Age Group Distribution (Donut Style)', fontsize=14)
plt.show()

# %% [markdown]
# ### Now move to analysis on Second dataset file
